# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50,ResNet152

# %%
input_shape = (32,32,3)

# %%
input_layer = Input(input_shape)

# %%
resnet50_mnodel = ResNet50(include_top=False, weights="imagenet", input_tensor=input_layer)
resnet152_model = ResNet152(include_top=False, weights="imagenet", input_tensor=input_layer)
# Out:
# ...
# 234700800/234698864 [==============================] - 17s 0us/step

# %%
resnet50_mnodel.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 16, 16, 64)   0           conv1_bn[0][0]
# ...

# %%
resnet50_mnodel.get_layer("input_1").output
# Out:
# <tf.Tensor 'input_1:0' shape=(None, 32, 32, 3) dtype=float32>

# %%
resnet50_mnodel.get_layer("conv1_relu").output
# Out:
# <tf.Tensor 'conv1_relu/Identity:0' shape=(None, 16, 16, 64) dtype=float32>
